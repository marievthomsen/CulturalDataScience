# %% [markdown]
# # Build your own concordance
#
# It took 500 Dominican munks to write the first concordance of the Latin bible, and it took Rabbi Mordecai Nathan 10 years to write the first concordance of the Hebrew bible. With Python, it only takes a matter of seconds to find words in a text, along with the surrounding words.
#
# Run each cell in this notebook one at a time, in order. If something in one cell doesn't work right, it might be because you have overwritten a variable, so try going back and running all the previous cells again.
#
# First run the code and check that everything works. Then, try modifying the code. Start with the first challenges, and then continue in order. Feel free to work together, and see how far you can get. The important thing is to learn, not to solve all the challenges!

# %%
# install the natural language toolkit package (nltk), which has a copy of several texts, 
#including the King James Bible

# %pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Collecting joblib (from nltk)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.2)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.6 MB/s eta 0:00:00ta 0:00:01
# Downloading regex-2024.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (782 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.7/782.7 kB 2.5 MB/s eta 0:00:00ta 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Installing collected packages: regex, joblib, nltk
# Successfully installed joblib-1.4.2 nltk-3.9.1 regex-2024.9.11
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the nltk package so that it is accessible to Python, and download a collection of texts from Project Gutenberg
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /home/ucloud/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
# Create a variable called "bible" which contains the text of the King James bible.
bible = nltk.corpus.gutenberg.raw('bible-kjv.txt')

# make all characters lowercase
bible = bible.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
bible = bible.replace('\n', ' ')

# split up the text into a long list of individual words
bible = bible.split(' ')

# %%
# make a variable called "concordance", and fill it with every occurrence of the phrase "this world", and a few words preceeding and following "this world"
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        if bible[i-1] == "this":
            concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['for the children of this world are in their generation',
#  'them, the children of this world marry, and are given',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'for the prince of this world cometh, and hath nothing',
#  'because the prince of this world is judged.  16:12',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'for the fashion of this world passeth away.  7:32',
#  'whom the god of this world hath blinded the minds',
#  'chosen the poor of this world rich in faith, and',
#  'saying, the kingdoms of this world are become the kingdoms']

# %%
# let's see how many instances of the phrase "this world" were found
len(concordance)
# Out:
# 13

# %% [markdown]
# Let's try again, but this time let's just search for "world" by itself, not "this world".

# %%
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['and he hath set the world upon them.  2:9',
#  'appeared, the foundations of the world were discovered, at the',
#  'him, all the earth: the world also shall be stable,',
#  'upon the face of the world in the earth. ',
#  'and he shall judge the world in righteousness, he shall',
#  'and the foundations of the world were discovered at thy',
#  'all the ends of the world shall remember and turn',
#  'all the inhabitants of the world stand in awe of',
#  'not tell thee: for the world is mine, and the',
#  'is thine: as for the world and the fulness thereof,',
#  'he hath girded himself: the world also is stablished, that',
#  'that the lord reigneth: the world also shall be established',
#  'earth: he shall judge the world with righteousness, and the',
#  'also he hath set the world in their heart, so',
#  'and i will punish the world for their evil, and',
#  'kingdoms; 14:17 that made the world as a wilderness, and',
#  'fill the face of the world with cities.  14:22',
#  'all the kingdoms of the world upon the face of',
#  'mourneth and fadeth away, the world languisheth and fadeth away,',
#  'earth, the inhabitants of the world will learn righteousness. ',
#  'have the inhabitants of the world fallen.  26:19 thy',
#  'fill the face of the world with fruit.  27:7',
#  'not be ashamed nor confounded world without end.  45:18',
#  'since the beginning of the world men have not heard,',
#  'power, he hath established the world by his wisdom, and',
#  'power, he hath established the world by his wisdom, and',
#  'this world, neither in the world to come.  12:33',
#  ' 18:7 woe unto the world because of offences! for',
#  'be preached in all the world for a witness unto',
#  'since the beginning of the world to this time, no,',
#  'with persecutions; and in the world to come eternal life.',
#  'which have been since the world began: 1:71 that we',
#  'caesar augustus that all the world should be taxed. ',
#  'all the kingdoms of the world in a moment of',
#  'do the nations of the world seek after: and your',
#  'for the children of this world are in their generation',
#  'present time, and in the world to come life everlasting.',
#  'them, the children of this world marry, and are given',
#  'in the world, and the world was made by him,',
#  'made by him, and the world knew him not. ',
#  'not his son into the world to condemn the world;',
#  'the world; but that the world through him might be',
#  'alway ready.  7:7 the world cannot hate you; but',
#  'and i speak to the world those things which i',
#  'heareth.  9:32 since the world began was it not',
#  'ye prevail nothing? behold, the world is gone after him.',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'spirit of truth; whom the world cannot receive, because it',
#  'a little while, and the world seeth me no more;',
#  'unto you: not as the world giveth, give i unto',
#  'for the prince of this world cometh, and hath nothing',
#  ' 14:31 but that the world may know that i',
#  'another.  15:18 if the world hate you, ye know',
#  'were of the world, the world would love his own:',
#  'of the world, therefore the world hateth you.  15:20',
#  'come, he will reprove the world of sin, and of',
#  'because the prince of this world is judged.  16:12',
#  'weep and lament, but the world shall rejoice: and ye',
#  'have peace.  in the world ye shall have tribulation:',
#  'had with thee before the world was.  17:6 i',
#  'them thy word; and the world hath hated them, because',
#  'one in us: that the world may believe that thou',
#  'in one; and that the world may know that thou',
#  '17:25 o righteous father, the world hath not known thee:',
#  'i suppose that even the world itself could not contain',
#  'his holy prophets since the world began.  3:22 for',
#  'these that have turned the world upside down are come',
#  '17:24 god that made the world and all things therein,',
#  'which he will judge the world in righteousness by that',
#  'whom all asia and the world worshippeth.  19:28 and',
#  'from the creation of the world are clearly seen, being',
#  'be stopped, and all the world may become guilty before',
#  'was kept secret since the world began, 16:26 but now',
#  'the wisdom of god the world by wisdom knew not',
#  'the foolish things of the world to confound the wise;',
#  'the weak things of the world to confound the things',
#  'which god ordained before the world unto our glory: 2:8',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'the world? and if the world shall be judged by',
#  'for the fashion of this world passeth away.  7:32',
#  'eat no flesh while the world standeth, lest i make',
#  'whom the ends of the world are come.  10:12',
#  'whom the god of this world hath blinded the minds',
#  'was in christ, reconciling the world unto himself, not imputing',
#  'but the sorrow of the world worketh death.  7:11',
#  'jesus christ, by whom the world is crucified unto me,',
#  'from the beginning of the world hath been hid in',
#  'christ jesus throughout all ages, world without end. amen. ',
#  'christ jesus came into the world to save sinners; of',
#  'in christ jesus before the world began, 1:10 but is',
#  'cannot lie, promised before the world began; 1:3 but hath',
#  'not put in subjection the world to come, whereof we',
#  'and the powers of the world to come, 6:6 if',
#  'in the end of the world hath he appeared to',
#  'tormented; 11:38 (of whom the world was not worthy:) they',
#  'chosen the poor of this world rich in faith, and',
#  'tongue is a fire, a world of iniquity: so is',
#  'that the friendship of the world is enmity with god?',
#  'be a friend of the world is the enemy of',
#  'corruption that is in the world through lust.  1:5',
#  'in the flood upon the world of the ungodly; 2:6',
#  'escaped the pollutions of the world through the knowledge of',
#  'the water: 3:6 whereby the world that then was, being',
#  'world.  2:17 and the world passeth away, and the',
#  'sons of god: therefore the world knoweth us not, because',
#  'not, my brethren, if the world hate you.  3:14',
#  'of the world, and the world heareth them.  4:6',
#  'of god, and the whole world lieth in wickedness. ',
#  'saying, the kingdoms of this world are become the kingdoms',
#  'was healed: and all the world wondered after the beast.']

# %%
# let's see how many instances of just the word "world" were found
len(concordance)
# Out:
# 113

# %% [markdown]
# Now, in the cell below, modify the code to search for a different word.

# %%
# add your modified code here and run the cell...
concordance = []
for i, val in enumerate(bible):
    if val == "kingdom":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
len(concordance)
# Out:
# 253

# %%
concordance
# Out:
# ['and the beginning of his kingdom was babel, and erech,',
#  'on me and on my kingdom a great sin? thou',
#  'shall be unto me a kingdom of priests, and an',
#  'higher than agag, and his kingdom shall be exalted. ',
#  'the son of joseph, the kingdom of sihon king of',
#  'of the amorites, and the kingdom of og king of',
#  'the region of argob, the kingdom of og in bashan.',
#  'and edrei, cities of the kingdom of og in bashan.',
#  'and all bashan, being the kingdom of og, gave i',
#  'unto salcah; 13:12 all the kingdom of og in bashan,',
#  'the plain, and all the kingdom of sihon king of',
#  'zaphon, the rest of the kingdom of sihon king of',
#  'mahanaim, all bashan, all the kingdom of og king of',
#  'and edrei, cities of the kingdom of og in bashan,',
#  'to gilgal, and renew the kingdom there.  11:15 and',
#  'the lord have established thy kingdom upon israel for ever.',
#  ' 13:14 but now thy kingdom shall not continue: the',
#  '14:47 so saul took the kingdom over israel, and fought',
#  'the lord hath rent the kingdom of israel from thee',
#  'be king, and that the kingdom of israel shall be',
#  'the lord hath rent the kingdom out of thine hand,',
#  'him; 3:10 to translate the kingdom from the house of',
#  'he said, i and my kingdom are guiltless before the',
#  "that he had exalted his kingdom for his people israel's",
#  'stablish the throne of his kingdom for ever.  7:14',
#  'and thine house and thy kingdom shall be established for',
#  'of israel restore me the kingdom of my father. ',
#  'the lord hath delivered the kingdom into the hand of',
#  'david his father; and his kingdom was established greatly. ',
#  'said, thou knowest that the kingdom was mine, and that',
#  'i should reign: howbeit the kingdom is turned about, and',
#  'adonijah? ask for him the kingdom also; for he is',
#  'that he died. and the kingdom was established in the',
#  'establish the throne of thy kingdom upon israel for ever,',
#  'i will surely rend the kingdom from thee, and will',
#  'behold, i will rend the kingdom out of the hand',
#  'will not take the whole kingdom out of his hand:',
#  "but i will take the kingdom out of his son's",
#  'of israel, to bring the kingdom again to rehoboam the',
#  'his heart, now shall the kingdom return to the house',
#  'israel, 14:8 and rent the kingdom away from the house',
#  'took an oath of the kingdom and nation, that they',
#  'dost thou now govern the kingdom of israel? arise, and',
#  'pass, as soon as the kingdom was confirmed in his',
#  'with him to confirm the kingdom in his hand. ',
#  'slew him, and turned the kingdom unto david the son',
#  'to hebron, to turn the kingdom of saul to him,',
#  'king over israel, for his kingdom was lifted up on',
#  'to nation, and from one kingdom to another people; 16:21',
#  'mine house and in my kingdom for ever: and his',
#  'establish the throne of his kingdom over israel for ever.',
#  'upon the throne of the kingdom of the lord over',
#  'moreover i will establish his kingdom for ever, if he',
#  'that he might bring the kingdom again to rehoboam. ',
#  '11:17 so they strengthened the kingdom of judah, and made',
#  'god of israel gave the kingdom over israel to david',
#  'ye think to withstand the kingdom of the lord in',
#  'and the images: and the kingdom was quiet before him.',
#  'therefore the lord stablished the kingdom in his hand; and',
#  'cities in judah: but the kingdom gave he to jehoram;',
#  'was risen up to the kingdom of his father, he',
#  'came to pass, when the kingdom was established to him,',
#  'god of any nation or kingdom was able to deliver',
#  'until the reign of the kingdom of persia: 36:21 to',
#  'the riches of his glorious kingdom and the honour of',
#  'that were throughout the whole kingdom of ahasuerus, even the',
#  'thou art come to the kingdom for such a time',
#  'to the half of the kingdom it shall be performed.',
#  'and seven provinces of the kingdom of ahasuerus, with words',
#  "thee.  22:28 for the kingdom is the lord's: and",
#  'ever: the sceptre of thy kingdom is a right sceptre.',
#  'in the heavens; and his kingdom ruleth over all. ',
#  'nation to another, from one kingdom to another people; ',
#  'his kingdom.  145:13 thy kingdom is an everlasting kingdom,',
#  'that is born in his kingdom becometh poor.  4:15',
#  'cease from ephraim, and the kingdom from damascus, and the',
#  'neighbour; city against city, and kingdom against kingdom.  19:3',
#  '60:12 for the nation and kingdom that will not serve',
#  'pass, that the nation and kingdom which will not serve',
#  'ground: he hath polluted the kingdom and the princes thereof.',
#  'the land: 17:14 that the kingdom might be base, that',
#  'after thee shall arise another kingdom inferior to thee, and',
#  'to thee, and another third kingdom of brass, which shall',
#  ' 2:40 and the fourth kingdom shall be strong as',
#  'and part of iron, the kingdom shall be divided; but',
#  'part of clay, so the kingdom shall be partly strong,',
#  'never be destroyed: and the kingdom shall not be left',
#  'mighty are his wonders! his kingdom is an everlasting kingdom,',
#  'most high ruleth in the kingdom of men, and giveth',
#  'the wise men of my kingdom are not able to',
#  'most high ruleth in the kingdom of men, and giveth',
#  'of the tree roots; thy kingdom shall be sure unto',
#  'in the palace of the kingdom of babylon.  4:30',
#  'for the house of the kingdom by the might of',
#  'thee it is spoken; the kingdom is departed from thee.',
#  'most high ruleth in the kingdom of men, and giveth',
#  'an everlasting dominion, and his kingdom is from generation to',
#  'high god ruled in the kingdom of men, and that',
#  'wanting.  5:28 peres; thy kingdom is divided, and given',
#  'darius to set over the kingdom an hundred and twenty',
#  'in every dominion of my kingdom men tremble and fear',
#  'stedfast for ever, and his kingdom that which shall not',
#  'not pass away, and his kingdom that which shall not',
#  'the kingdom, and possess the kingdom for ever, even for',
#  'beast shall be the fourth kingdom upon earth, which shall',
#  'ten horns out of this kingdom are ten kings that',
#  'end.  7:27 and the kingdom and dominion, and the',
#  'and the greatness of the kingdom under the whole heaven,',
#  'of the most high, whose kingdom is an everlasting kingdom,',
#  'but the prince of the kingdom of persia withstood me',
#  'he shall stand up, his kingdom shall be broken, and',
#  'which he ruled: for his kingdom shall be plucked up,',
#  'in peaceably, and obtain the kingdom by flatteries.  11:22',
#  'will cause to cease the kingdom of the house of',
#  "mount of esau; and the kingdom shall be the lord's.",
#  'even the first dominion; the kingdom shall come to the',
#  'saying, repent ye: for the kingdom of heaven is at',
#  'to say, repent: for the kingdom of heaven is at',
#  'spirit: for theirs is the kingdom of heaven.  5:4',
#  'sake: for theirs is the kingdom of heaven.  5:11',
#  'called the least in the kingdom of heaven: but whosoever',
#  'be called great in the kingdom of heaven.  5:20',
#  'no case enter into the kingdom of heaven.  5:21',
#  'thy name.  6:10 thy kingdom come, thy will be',
#  'but seek ye first the kingdom of god, and his',
#  'lord, shall enter into the kingdom of heaven; but he',
#  'isaac, and jacob, in the kingdom of heaven.  8:12',
#  'but the children of the kingdom shall be cast out',
#  'ye go, preach, saying, the kingdom of heaven is at',
#  'that is least in the kingdom of heaven is greater',
#  'the baptist until now the kingdom of heaven suffereth violence,',
#  'and said unto them, every kingdom divided against itself is',
#  'himself; how shall then his kingdom stand?  12:27 and',
#  'spirit of god, then the kingdom of god is come',
#  'know the mysteries of the kingdom of heaven, but to',
#  'forth unto them, saying, the kingdom of heaven is likened',
#  'forth unto them, saying, the kingdom of heaven is like',
#  'spake he unto them; the kingdom of heaven is like',
#  'shall gather out of his kingdom all things that offend,',
#  'as the sun in the kingdom of their father. who',
#  'hear.  13:44 again, the kingdom of heaven is like',
#  'field.  13:45 again, the kingdom of heaven is like',
#  'it.  13:47 again, the kingdom of heaven is like',
#  'which is instructed unto the kingdom of heaven is like',
#  'thee the keys of the kingdom of heaven: and whatsoever',
#  'is the greatest in the kingdom of heaven?  18:2',
#  'shall not enter into the kingdom of heaven.  18:4',
#  'same is greatest in the kingdom of heaven.  18:5',
#  ' 18:23 therefore is the kingdom of heaven likened unto',
#  "made themselves eunuchs for the kingdom of heaven's sake. he",
#  'for of such is the kingdom of heaven.  19:15',
#  'shall hardly enter into the kingdom of heaven.  19:24',
#  'man to enter into the kingdom of god.  19:25',
#  'first.  20:1 for the kingdom of heaven is like',
#  'the harlots go into the kingdom of god before you.',
#  'say i unto you, the kingdom of god shall be',
#  'parables, and said, 22:2 the kingdom of heaven is like',
#  'for ye shut up the kingdom of heaven against men:',
#  'shall rise against nation, and kingdom against kingdom: and there',
#  'and this gospel of the kingdom shall be preached in',
#  ' 25:1 then shall the kingdom of heaven be likened',
#  'cometh.  25:14 for the kingdom of heaven is as',
#  'of my father, inherit the kingdom prepared for you from',
#  'preaching the gospel of the kingdom of god, 1:15 and',
#  'time is fulfilled, and the kingdom of god is at',
#  ' 3:24 and if a kingdom be divided against itself,',
#  'be divided against itself, that kingdom cannot stand.  3:25',
#  'know the mystery of the kingdom of god: but unto',
#  'he said, so is the kingdom of god, as if',
#  'whereunto shall we liken the kingdom of god? or with',
#  'till they have seen the kingdom of god come with',
#  'thee to enter into the kingdom of god with one',
#  'for of such is the kingdom of god.  10:15',
#  'whosoever shall not receive the kingdom of god as a',
#  'have riches enter into the kingdom of god! 10:24 and',
#  'riches to enter into the kingdom of god!  10:25',
#  'man to enter into the kingdom of god.  10:26',
#  'lord: 11:10 blessed be the kingdom of our father david,',
#  'art not far from the kingdom of god. and no',
#  'shall rise against nation, and kingdom against kingdom: and there',
#  'drink it new in the kingdom of god.  14:26',
#  'which also waited for the kingdom of god, came, and',
#  'for ever; and of his kingdom there shall be no',
#  'them, i must preach the kingdom of god to other',
#  'poor: for yours is the kingdom of god.  6:21',
#  'that is least in the kingdom of god is greater',
#  'the glad tidings of the kingdom of god: and the',
#  'know the mysteries of the kingdom of god: but to',
#  'sent them to preach the kingdom of god, and to',
#  'spake unto them of the kingdom of god, and healed',
#  'death, till they see the kingdom of god.  9:28',
#  'go thou and preach the kingdom of god.  9:61',
#  'back, is fit for the kingdom of god.  10:1',
#  'and say unto them, the kingdom of god is come',
#  'sure of this, that the kingdom of god is come',
#  'hallowed be thy name. thy kingdom come. thy will be',
#  'thoughts, said unto them, every kingdom divided against itself is',
#  'against himself, how shall his kingdom stand? because ye say',
#  'out devils, no doubt the kingdom of god is come',
#  'but rather seek ye the kingdom of god; and all',
#  'he, unto what is the kingdom of god like? and',
#  'whereunto shall i liken the kingdom of god? 13:21 it',
#  'all the prophets, in the kingdom of god, and you',
#  'shall sit down in the kingdom of god.  13:30',
#  'shall eat bread in the kingdom of god.  14:16',
#  'john: since that time the kingdom of god is preached,',
#  'of the pharisees, when the kingdom of god should come,',
#  'answered them and said, the kingdom of god cometh not',
#  'lo there! for, behold, the kingdom of god is within',
#  'for of such is the kingdom of god.  18:17',
#  'whosoever shall not receive the kingdom of god as a',
#  'have riches enter into the kingdom of god! 18:25 for',
#  'man to enter into the kingdom of god.  18:26',
#  "wife, or children, for the kingdom of god's sake, 18:30",
#  'because they thought that the kingdom of god should immediately',
#  'shall rise against nation, and kingdom against kingdom: 21:11 and',
#  'pass, know ye that the kingdom of god is nigh',
#  'it be fulfilled in the kingdom of god.  22:17',
#  'of the vine, until the kingdom of god shall come.',
#  'also himself waited for the kingdom of god.  23:52',
#  'again, he cannot see the kingdom of god.  3:4',
#  'he cannot enter into the kingdom of god.  3:6',
#  'done? 18:36 jesus answered, my kingdom is not of this',
#  'of this world: if my kingdom were of this world,',
#  'jews: but now is my kingdom not from hence. ',
#  'the things pertaining to the kingdom of god: 1:4 and,',
#  'this time restore again the kingdom to israel?  1:7',
#  'preaching the things concerning the kingdom of god, and the',
#  'much tribulation enter into the kingdom of god.  14:23',
#  'persuading the things concerning the kingdom of god.  19:9',
#  'i have gone preaching the kingdom of god, shall see',
#  'he expounded and testified the kingdom of god, persuading them',
#  'unto him, 28:31 preaching the kingdom of god, and teaching',
#  'spoken of: 14:17 for the kingdom of god is not',
#  'power.  4:20 for the kingdom of god is not',
#  'unrighteous shall not inherit the kingdom of god?  be',
#  'nor extortioners, shall inherit the kingdom of god.  6:11',
#  'shall have delivered up the kingdom to god, even the',
#  'and blood cannot inherit the kingdom of god; neither doth',
#  'things shall not inherit the kingdom of god.  5:22',
#  'hath any inheritance in the kingdom of christ and of',
#  'hath translated us into the kingdom of his dear son:',
#  'are my fellowworkers unto the kingdom of god, which have',
#  'hath called you unto his kingdom and glory.  2:13',
#  'be counted worthy of the kingdom of god, for which',
#  '12:28 wherefore we receiving a kingdom which cannot be moved,',
#  'faith, and heirs of the kingdom which he hath promised',
#  'you abundantly into the everlasting kingdom of our lord and',
#  'in tribulation, and in the kingdom and patience of jesus',
#  'salvation, and strength, and the kingdom of our god, and',
#  'of the beast; and his kingdom was full of darkness;',
#  'kings, which have received no kingdom as yet; but receive',
#  'to agree, and give their kingdom unto the beast, until']

# %% [markdown]
# The nltk package has the full text of several other classic books. You can see what they are called by running the command in the cell below:

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# ## Your turn!
#
# Here are a some more things you can try. In each case, I have given you a little bit of starter code to get you going, but the cells will not run without some additional code from you.

# %% [markdown]
# ## Challenge 1: build your own concordance
#
# Pick a different book and a different word, or pair of words. Copy and paste from the code above to write some Python code that searches the book of your choice for the word or pair of words of your choice. Put this code in the cell below. By the way, some of the texts use the characters "\r" for "carriage return" instead of "\n" for "newline". You can remove these the same way that you remove the "\n" characters.

# %%
# add your code to search for a word or pair of words in a different book here

# Create a variable called "bible" which contains the text of the King James bible.
macbeth = nltk.corpus.gutenberg.raw('shakespeare-macbeth.txt')

# make all characters lowercase
macbeth = macbeth.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
macbeth = macbeth.replace('\n', ' ')

# split up the text into a long list of individual words
macbeth = macbeth.split(' ')

# %%
macbeth
# Out:
# ['[the',
#  'tragedie',
#  'of',
#  'macbeth',
#  'by',
#  'william',
#  'shakespeare',
#  '1603]',
#  '',
#  '',
#  'actus',
#  'primus.',
#  'scoena',
#  'prima.',
#  '',
#  'thunder',
#  'and',
#  'lightning.',
#  'enter',
#  'three',
#  'witches.',
#  '',
#  '',
#  '',
#  '1.',
#  'when',
#  'shall',
#  'we',
#  'three',
#  'meet',
#  'againe?',
#  'in',
#  'thunder,',
#  'lightning,',
#  'or',
#  'in',
#  'raine?',
#  '',
#  '',
#  '2.',
#  'when',
#  'the',
#  "hurley-burley's",
#  'done,',
#  'when',
#  'the',
#  "battaile's",
#  'lost,',
#  'and',
#  'wonne',
#  '',
#  '',
#  '',
#  '',
#  '3.',
#  'that',
#  'will',
#  'be',
#  'ere',
#  'the',
#  'set',
#  'of',
#  'sunne',
#  '',
#  '',
#  '',
#  '',
#  '1.',
#  'where',
#  'the',
#  'place?',
#  '',
#  '',
#  '2.',
#  'vpon',
#  'the',
#  'heath',
#  '',
#  '',
#  '',
#  '',
#  '3.',
#  'there',
#  'to',
#  'meet',
#  'with',
#  'macbeth',
#  '',
#  '',
#  '',
#  '',
#  '1.',
#  'i',
#  'come,',
#  'gray-malkin',
#  '',
#  '',
#  '',
#  '',
#  'all.',
#  'padock',
#  'calls',
#  'anon:',
#  'faire',
#  'is',
#  'foule,',
#  'and',
#  'foule',
#  'is',
#  'faire,',
#  'houer',
#  'through',
#  'the',
#  'fogge',
#  'and',
#  'filthie',
#  'ayre.',
#  '',
#  'exeunt.',
#  '',
#  '',
#  'scena',
#  'secunda.',
#  '',
#  'alarum',
#  'within.',
#  'enter',
#  'king',
#  'malcome,',
#  'donalbaine,',
#  'lenox,',
#  'with',
#  'attendants,',
#  'meeting',
#  'a',
#  'bleeding',
#  'captaine.',
#  '',
#  '',
#  '',
#  'king.',
#  'what',
#  'bloody',
#  'man',
#  'is',
#  'that?',
#  'he',
#  'can',
#  'report,',
#  'as',
#  'seemeth',
#  'by',
#  'his',
#  'plight,',
#  'of',
#  'the',
#  'reuolt',
#  'the',
#  'newest',
#  'state',
#  '',
#  '',
#  '',
#  '',
#  'mal.',
#  'this',
#  'is',
#  'the',
#  'serieant,',
#  'who',
#  'like',
#  'a',
#  'good',
#  'and',
#  'hardie',
#  'souldier',
#  'fought',
#  "'gainst",
#  'my',
#  'captiuitie:',
#  'haile',
#  'braue',
#  'friend;',
#  'say',
#  'to',
#  'the',
#  'king,',
#  'the',
#  'knowledge',
#  'of',
#  'the',
#  'broyle,',
#  'as',
#  'thou',
#  'didst',
#  'leaue',
#  'it',
#  '',
#  '',
#  '',
#  '',
#  'cap.',
#  'doubtfull',
#  'it',
#  'stood,',
#  'as',
#  'two',
#  'spent',
#  'swimmers,',
#  'that',
#  'doe',
#  'cling',
#  'together,',
#  'and',
#  'choake',
#  'their',
#  'art:',
#  'the',
#  'mercilesse',
#  'macdonwald',
#  '(worthie',
#  'to',
#  'be',
#  'a',
#  'rebell,',
#  'for',
#  'to',
#  'that',
#  'the',
#  'multiplying',
#  'villanies',
#  'of',
#  'nature',
#  'doe',
#  'swarme',
#  'vpon',
#  'him)',
#  'from',
#  'the',
#  'westerne',
#  'isles',
#  'of',
#  'kernes',
#  'and',
#  'gallowgrosses',
#  'is',
#  "supply'd,",
#  'and',
#  'fortune',
#  'on',
#  'his',
#  'damned',
#  'quarry',
#  'smiling,',
#  "shew'd",
#  'like',
#  'a',
#  'rebells',
#  'whore:',
#  'but',
#  "all's",
#  'too',
#  'weake:',
#  'for',
#  'braue',
#  'macbeth',
#  '(well',
#  'hee',
#  'deserues',
#  'that',
#  'name)',
#  'disdayning',
#  'fortune,',
#  'with',
#  'his',
#  'brandisht',
#  'steele,',
#  'which',
#  "smoak'd",
#  'with',
#  'bloody',
#  'execution',
#  '(like',
#  'valours',
#  'minion)',
#  "caru'd",
#  'out',
#  'his',
#  'passage,',
#  'till',
#  'hee',
#  "fac'd",
#  'the',
#  'slaue:',
#  'which',
#  "neu'r",
#  'shooke',
#  'hands,',
#  'nor',
#  'bad',
#  'farwell',
#  'to',
#  'him,',
#  'till',
#  'he',
#  "vnseam'd",
#  'him',
#  'from',
#  'the',
#  'naue',
#  "toth'",
#  'chops,',
#  'and',
#  "fix'd",
#  'his',
#  'head',
#  'vpon',
#  'our',
#  'battlements',
#  '',
#  '',
#  '',
#  '',
#  'king.',
#  'o',
#  'valiant',
#  'cousin,',
#  'worthy',
#  'gentleman',
#  '',
#  '',
#  '',
#  '',
#  'cap.',
#  'as',
#  'whence',
#  'the',
#  'sunne',
#  "'gins",
#  'his',
#  'reflection,',
#  'shipwracking',
#  'stormes,',
#  'and',
#  'direfull',
#  'thunders:',
#  'so',
#  'from',
#  'that',
#  'spring,',
#  'whence',
#  'comfort',
#  "seem'd",
#  'to',
#  'come,',
#  'discomfort',
#  'swells:',
#  'marke',
#  'king',
#  'of',
#  'scotland,',
#  'marke,',
#  'no',
#  'sooner',
#  'iustice',
#  'had,',
#  'with',
#  'valour',
#  "arm'd,",
#  "compell'd",
#  'these',
#  'skipping',
#  'kernes',
#  'to',
#  'trust',
#  'their',
#  'heeles,',
#  'but',
#  'the',
#  'norweyan',
#  'lord,',
#  'surueying',
#  'vantage,',
#  'with',
#  'furbusht',
#  'armes,',
#  'and',
#  'new',
#  'supplyes',
#  'of',
#  'men,',
#  'began',
#  'a',
#  'fresh',
#  'assault',
#  '',
#  '',
#  '',
#  '',
#  'king.',
#  "dismay'd",
#  'not',
#  'this',
#  'our',
#  'captaines,',
#  'macbeth',
#  'and',
#  'banquoh?',
#  '',
#  '',
#  'cap.',
#  'yes,',
#  'as',
#  'sparrowes,',
#  'eagles;',
#  'or',
#  'the',
#  'hare,',
#  'the',
#  'lyon:',
#  'if',
#  'i',
#  'say',
#  'sooth,',
#  'i',
#  'must',
#  'report',
#  'they',
#  'were',
#  'as',
#  'cannons',
#  "ouer-charg'd",
#  'with',
#  'double',
#  'cracks,',
#  'so',
#  'they',
#  'doubly',
#  'redoubled',
#  'stroakes',
#  'vpon',
#  'the',
#  'foe:',
#  'except',
#  'they',
#  'meant',
#  'to',
#  'bathe',
#  'in',
#  'reeking',
#  'wounds,',
#  'or',
#  'memorize',
#  'another',
#  'golgotha,',
#  'i',
#  'cannot',
#  'tell:',
#  'but',
#  'i',
#  'am',
#  'faint,',
#  'my',
#  'gashes',
#  'cry',
#  'for',
#  'helpe',
#  '',
#  '',
#  '',
#  '',
#  'king.',
#  'so',
#  'well',
#  'thy',
#  'words',
#  'become',
#  'thee,',
#  'as',
#  'thy',
#  'wounds,',
#  'they',
#  'smack',
#  'of',
#  'honor',
#  'both:',
#  'goe',
#  'get',
#  'him',
#  'surgeons.',
#  'enter',
#  'rosse',
#  'and',
#  'angus.',
#  '',
#  'who',
#  'comes',
#  'here?',
#  '',
#  '',
#  'mal.',
#  'the',
#  'worthy',
#  'thane',
#  'of',
#  'rosse',
#  '',
#  '',
#  '',
#  '',
#  'lenox.',
#  'what',
#  'a',
#  'haste',
#  'lookes',
#  'through',
#  'his',
#  'eyes?',
#  'so',
#  'should',
#  'he',
#  'looke,',
#  'that',
#  'seemes',
#  'to',
#  'speake',
#  'things',
#  'strange',
#  '',
#  '',
#  '',
#  '',
#  'rosse.',
#  'god',
#  'saue',
#  'the',
#  'king',
#  '',
#  '',
#  '',
#  '',
#  'king.',
#  'whence',
#  "cam'st",
#  'thou,',
#  'worthy',
#  'thane?',
#  '',
#  '',
#  'rosse.',
#  'from',
#  'fiffe,',
#  'great',
#  'king,',
#  'where',
#  'the',
#  'norweyan',
#  'banners',
#  'flowt',
#  'the',
#  'skie,',
#  'and',
#  'fanne',
#  'our',
#  'people',
#  'cold.',
#  'norway',
#  'himselfe,',
#  'with',
#  'terrible',
#  'numbers,',
#  'assisted',
#  'by',
#  'that',
#  'most',
#  'disloyall',
#  'traytor,',
#  'the',
#  'thane',
#  'of',
#  'cawdor,',
#  'began',
#  'a',
#  'dismall',
#  'conflict,',
#  'till',
#  'that',
#  "bellona's",
#  'bridegroome,',
#  'lapt',
#  'in',
#  'proofe,',
#  'confronted',
#  'him',
#  'with',
#  'selfe-comparisons,',
#  'point',
#  'against',
#  'point,',
#  'rebellious',
#  'arme',
#  "'gainst",
#  'arme,',
#  'curbing',
#  'his',
#  'lauish',
#  'spirit:',
#  'and',
#  'to',
#  'conclude,',
#  'the',
#  'victorie',
#  'fell',
#  'on',
#  'vs',
#  '',
#  '',
#  '',
#  '',
#  'king.',
#  'great',
#  'happinesse',
#  '',
#  '',
#  '',
#  '',
#  'rosse.',
#  'that',
#  'now',
#  'sweno,',
#  'the',
#  'norwayes',
#  'king,',
#  'craues',
#  'composition:',
#  'nor',
#  'would',
#  'we',
#  'deigne',
#  'him',
#  'buriall',
#  'of',
#  'his',
#  'men,',
#  'till',
#  'he',
#  'disbursed,',
#  'at',
#  'saint',
#  'colmes',
#  'ynch,',
#  'ten',
#  'thousand',
#  'dollars,',
#  'to',
#  'our',
#  'generall',
#  'vse',
#  '',
#  '',
#  '',
#  '',
#  'king.',
#  'no',
#  'more',
#  'that',
#  'thane',
#  'of',
#  'cawdor',
#  'shall',
#  'deceiue',
#  'our',
#  'bosome',
#  'interest:',
#  'goe',
#  'pronounce',
#  'his',
#  'present',
#  'death,',
#  'and',
#  'with',
#  'his',
#  'former',
#  'title',
#  'greet',
#  'macbeth',
#  '',
#  '',
#  '',
#  '',
#  'rosse.',
#  'ile',
#  'see',
#  'it',
#  'done',
#  '',
#  '',
#  '',
#  '',
#  'king.',
#  'what',
#  'he',
#  'hath',
#  'lost,',
#  'noble',
#  'macbeth',
#  'hath',
#  'wonne.',
#  '',
#  'exeunt.',
#  '',
#  '',
#  'scena',
#  'tertia.',
#  '',
#  'thunder.',
#  'enter',
#  'the',
#  'three',
#  'witches.',
#  '',
#  '',
#  '',
#  '1.',
#  'where',
#  'hast',
#  'thou',
#  'beene,',
#  'sister?',
#  '',
#  '',
#  '2.',
#  'killing',
#  'swine',
#  '',
#  '',
#  '',
#  '',
#  '3.',
#  'sister,',
#  'where',
#  'thou?',
#  '',
#  '',
#  '1.',
#  'a',
#  'saylors',
#  'wife',
#  'had',
#  'chestnuts',
#  'in',
#  'her',
#  'lappe,',
#  'and',
#  'mouncht,',
#  '&',
#  'mouncht,',
#  'and',
#  'mouncht:',
#  'giue',
#  'me,',
#  'quoth',
#  'i.',
#  'aroynt',
#  'thee,',
#  'witch,',
#  'the',
#  'rumpe-fed',
#  'ronyon',
#  'cryes.',
#  'her',
#  "husband's",
#  'to',
#  'aleppo',
#  'gone,',
#  'master',
#  "o'th'",
#  'tiger:',
#  'but',
#  'in',
#  'a',
#  'syue',
#  'ile',
#  'thither',
#  'sayle,',
#  'and',
#  'like',
#  'a',
#  'rat',
#  'without',
#  'a',
#  'tayle,',
#  'ile',
#  'doe,',
#  'ile',
#  'doe,',
#  'and',
#  'ile',
#  'doe',
#  '',
#  '',
#  '',
#  '',
#  '2.',
#  'ile',
#  'giue',
#  'thee',
#  'a',
#  'winde',
#  '',
#  '',
#  '',
#  '',
#  '1.',
#  "th'art",
#  'kinde',
#  '',
#  '',
#  '',
#  '',
#  '3.',
#  'and',
#  'i',
#  'another',
#  '',
#  '',
#  '',
#  '',
#  '1.',
#  'i',
#  'my',
#  'selfe',
#  'haue',
#  'all',
#  'the',
#  'other,',
#  'and',
#  'the',
#  'very',
#  'ports',
#  'they',
#  'blow,',
#  'all',
#  'the',
#  'quarters',
#  'that',
#  'they',
#  'know,',
#  "i'th'",
#  'ship-mans',
#  'card.',
#  'ile',
#  'dreyne',
#  'him',
#  'drie',
#  'as',
#  'hay:',
#  'sleepe',
#  'shall',
#  'neyther',
#  'night',
#  'nor',
#  'day',
#  'hang',
#  'vpon',
#  'his',
#  'pent-house',
#  'lid:',
#  'he',
#  'shall',
#  'liue',
#  'a',
#  'man',
#  'forbid:',
#  'wearie',
#  "seu'nights,",
#  'nine',
#  'times',
#  'nine,',
#  'shall',
#  'he',
#  'dwindle,',
#  'peake,',
#  'and',
#  'pine:',
#  'though',
#  'his',
#  'barke',
#  'cannot',
#  'be',
#  'lost,',
#  'yet',
#  'it',
#  'shall',
#  'be',
#  'tempest-tost.',
#  'looke',
#  'what',
#  'i',
#  'haue',
#  '',
#  '',
#  '',
#  '',
#  '2.',
#  'shew',
#  'me,',
#  'shew',
#  'me',
#  '',
#  '',
#  '',
#  '',
#  '1.',
#  'here',
#  'i',
#  'haue',
#  'a',
#  'pilots',
#  'thumbe,',
#  'wrackt,',
#  'as',
#  'homeward',
#  'he',
#  'did',
#  'come.',
#  '',
#  'drum',
#  'within.',
#  '',
#  '',
#  '',
#  '3.',
#  'a',
#  'drumme,',
#  'a',
#  'drumme:',
#  'macbeth',
#  'doth',
#  'come',
#  '',
#  '',
#  '',
#  '',
#  'all.',
#  'the',
#  'weyward',
#  'sisters,',
#  'hand',
#  'in',
#  'hand,',
#  'posters',
#  'of',
#  'the',
#  'sea',
#  'and',
#  'land,',
#  'thus',
#  'doe',
#  'goe,',
#  'about,',
#  'about,',
#  'thrice',
#  'to',
#  'thine,',
#  'and',
#  'thrice',
#  'to',
#  'mine,',
#  'and',
#  'thrice',
#  'againe,',
#  'to',
#  'make',
#  'vp',
#  'nine.',
#  'peace,',
#  'the',
#  "charme's",
#  'wound',
#  'vp.',
#  'enter',
#  'macbeth',
#  'and',
#  'banquo.',
#  '',
#  '',
#  '',
#  'macb.',
#  'so',
#  'foule',
#  'and',
#  'faire',
#  'a',
#  'day',
#  'i',
#  'haue',
#  'not',
#  'seene',
#  '',
#  ...]

# %%
# make a variable called "concordance", and fill it with every occurrence of the phrase "this world", and a few words preceeding and following "this world"
concordance = []
for i, val in enumerate(macbeth):
    if val == "macbeth":
        concordance.append(str(' '.join(macbeth[i-5:i+5])))

# %%
concordance
# Out:
# ['',
#  '3. there to meet with macbeth    ',
#  "all's too weake: for braue macbeth (well hee deserues that",
#  "dismay'd not this our captaines, macbeth and banquoh?  ",
#  'with his former title greet macbeth    ',
#  'what he hath lost, noble macbeth hath wonne.  exeunt.',
#  '3. a drumme, a drumme: macbeth doth come  ',
#  "the charme's wound vp. enter macbeth and banquo.  ",
#  'ouer the stage. then enter macbeth    ',
#  'voyce cry, sleep no more: macbeth does murther sleepe, the',
#  'cawdor shall sleepe no more: macbeth shall sleepe no more',
#  'selues: awake, awake,  exeunt. macbeth and lenox.  ring',
#  '  macd. those that macbeth hath slaine  ',
#  'the soueraignty will fall vpon macbeth    ',
#  'more.  senit sounded. enter macbeth as king, lady lenox,',
#  'with vs?   3. macbeth    ',
#  ' 2 appar. macbeth, macbeth, macbeth    ',
#  "frets, or where conspirers are: macbeth shall neuer vanquish'd be,",
#  "rise, and our high plac'd macbeth shall liue the lease",
#  'is so. but why stands macbeth thus amazedly? come sisters,',
#  '   malc. but macbeth is. a good and',
#  "they shall be open'd, blacke macbeth will seeme as pure",
#  "damn'd in euils, to top macbeth    ",
#  'is nothing but our leaue. macbeth is ripe for shaking,',
#  "  macb. my name's macbeth    ",
#  'alarums.  enter fighting, and macbeth slaine.  retreat, and']

# %% [markdown]
# ## Challenge 2: compare lengths of books
#
# We can use the command `len` to find how many items there are in a list. E.g., to find the number of words in the list called `bible`, above, we can write: `len(bible)`.
#
# Use the starter code below to find out which book in the books included in `nltk` has the most words.

# %%
# solution 1: print all the titles and numbers of words
# starter code:

books = nltk.corpus.gutenberg.fileids()

for title in books:
    book = nltk.corpus.gutenberg.raw(title)
    print('There are', len(book.split()), "words in", title)
# Out:
# There are 158167 words in austen-emma.txt
# There are 83308 words in austen-persuasion.txt
# There are 118675 words in austen-sense.txt
# There are 821133 words in bible-kjv.txt
# There are 6845 words in blake-poems.txt
# There are 45988 words in bryant-stories.txt
# There are 15870 words in burgess-busterbrown.txt
# There are 26443 words in carroll-alice.txt
# There are 81598 words in chesterton-ball.txt
# There are 71626 words in chesterton-brown.txt
# There are 57955 words in chesterton-thursday.txt
# There are 166070 words in edgeworth-parents.txt
# There are 212030 words in melville-moby_dick.txt
# There are 79659 words in milton-paradise.txt
# There are 20459 words in shakespeare-caesar.txt
# There are 29605 words in shakespeare-hamlet.txt
# There are 17741 words in shakespeare-macbeth.txt
# There are 122070 words in whitman-leaves.txt

# %%
# more advanced, for those with some Python experience, or those who want to google around..
# solution 2: make a list of titles and a list of wordcounts, zip them together, then sort them based on wordcount
# starter code:

books = nltk.corpus.gutenberg.fileids()

titles = []
numwords = []

for title in books:
    book = nltk.corpus.gutenberg.raw(title)
    word_count = len(book.split())  # Split the raw text into words and count them
    titles.append(title)
    numwords.append(word_count)

# Zip the titles and word counts together and sort them by word count
book_info = list(zip(titles, numwords))
book_info_sorted = sorted(book_info, key=lambda x: x[1], reverse=True)  # Sort in descending order of word count

# Print the sorted titles with word counts
for title, count in book_info_sorted:
    print(f'{title}: {count} words')
# Out:
# bible-kjv.txt: 821133 words
# melville-moby_dick.txt: 212030 words
# edgeworth-parents.txt: 166070 words
# austen-emma.txt: 158167 words
# whitman-leaves.txt: 122070 words
# austen-sense.txt: 118675 words
# austen-persuasion.txt: 83308 words
# chesterton-ball.txt: 81598 words
# milton-paradise.txt: 79659 words
# chesterton-brown.txt: 71626 words
# chesterton-thursday.txt: 57955 words
# bryant-stories.txt: 45988 words
# shakespeare-hamlet.txt: 29605 words
# carroll-alice.txt: 26443 words
# shakespeare-caesar.txt: 20459 words
# shakespeare-macbeth.txt: 17741 words
# burgess-busterbrown.txt: 15870 words
# blake-poems.txt: 6845 words

# %% [markdown]
# ## Challenge 3: what are the most frequent words?
#
# `nltk` has a built-in function called `FreqDist` which counts up how many times each word in a text occurs. So, if you have a list called `words` which contains all the words in a book, you can find the frequencies of all of them by writing `freq = nltk.FreqDist(words)`. You can then get the e.g. ten most common words by writing `freq.most_common(10)`. What are the ten most common words in Jane Austen's "Emma"? What about Herman Melville's "Moby Dick"?

# %%
# starter code:

book = nltk.corpus.gutenberg.raw('austen-emma.txt')
words = book.lower()
words = words.split()

freq = nltk.FreqDist(words)
common = freq.most_common(10)
print(common)
# Out:
# [('the', 5120), ('to', 5079), ('and', 4445), ('of', 4196), ('a', 3055), ('i', 2602), ('was', 2302), ('she', 2169), ('in', 2091), ('not', 2028)]

# %%
book = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')
words = book.lower()
words = words.split()

freq = nltk.FreqDist(words)
common = freq.most_common(10)
print(common)
# Out:
# [('the', 14226), ('of', 6545), ('and', 6238), ('a', 4597), ('to', 4518), ('in', 4058), ('that', 2744), ('his', 2485), ('it', 1765), ('i', 1724)]

# %% [markdown]
# ## Challenge 4: Remove stopwords
#
# Often, the most frequent words are not the most interesting ones. Words like "a" and "the" are so common in English, that they don't really tell us much about the text. That is why we often remove "stopwords", that is, a list of the most common words in English, before e.g. counting frequencies. There are several of these lists available, in [English]((https://gist.github.com/sebleier/554280)) as well as other languages, such as [Danish](https://gist.github.com/berteltorp/0cf8a0c7afea7f25ed754f24cfc2467b). Below is some starter code to remove stopwords. Use these snippets to see what the most common words in Emma and Moby Dick are after removing these most common words.
#
# Hint: In Moby Dick, you will also have to remove the string `\r`, in addition to removing `\n`.

# %%
# list of stopwords

stopwords = ["", "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
# starter code:

book = nltk.corpus.gutenberg.raw('austen-emma.txt')
words = book.lower()
words = words.split()

# code to remove stopwords.
words = [word for word in words if word not in stopwords]

freq = nltk.FreqDist(words)
common = freq.most_common(10)
print(common)
# Out:
# [('mr.', 1097), ('could', 800), ('would', 795), ('mrs.', 675), ('miss', 568), ('must', 543), ('emma', 481), ('much', 427), ('every', 425), ('said', 392)]

# %%
book = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')
book = book.replace('\n', ' ')
book = book.replace('\r',' ')
words = book.lower()
words = words.split()

# code to remove stopwords.
words = [word for word in words if word not in stopwords]

freq = nltk.FreqDist(words)
common = freq.most_common(10)
print(common)
# Out:
# [('one', 779), ('like', 564), ('upon', 556), ('whale', 528), ('old', 425), ('would', 416), ('though', 311), ('great', 292), ('still', 282), ('seemed', 273)]
